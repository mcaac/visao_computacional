# %% [markdown]
# # Zoom

# %% [markdown]
# ### Zoom_in_(1).png

# %%
import numpy as np
from PIL import Image
from PIL import ImageEnhance
from matplotlib import pyplot as plt

# %%
# Resizing the zoom_in 1
zoom_1 = Image.open("zoom/Zoom_in_(1).jpg")

# Com apenas um parenteses no método resize, deu o seguinte erro:
#  Unknown resampling filter (480). Use Image.NEAREST (0), Image.LANCZOS (1), Image.BILINEAR (2), 
# Image.BICUBIC (3), Image.BOX (4) or Image.HAMMING (5)
new_zoom_1 = zoom_1.resize((360, 480))
new_zoom_1.save("zoom/result/New_Zoom_in_(1).jpg")

# Zoom da nova imagem


# Retorna o formato da imagem, tamanho e Pixel type (L = Luminance, RBG = true color, CMYK = pre-press images)
print(zoom_1.format, zoom_1.size, zoom_1.mode)
print(new_zoom_1.format, new_zoom_1.size, new_zoom_1.mode)
# Out:
# JPEG (100, 150) L
# None (360, 480) L

# %% [markdown]
# ### Zoom_in_(2).png

# %%
# Resizing the zoom_in 2
zoom_2 = Image.open("zoom/Zoom_in_(2).jpg")
new_zoom_2 = zoom_2.resize((2592, 1456))
new_zoom_2.save("zoom/result/New_Zoom_in_(2).jpg")

print(zoom_2.format, zoom_2.size, zoom_2.mode)
print(new_zoom_2.format, new_zoom_2.size, new_zoom_2.mode)
# Out:
# JPEG (890, 500) L
# None (2592, 1456) L

# %% [markdown]
# ### Zoom_in_(3).png

# %%
# Resizing the zoom_in 3
zoom_3 = Image.open("zoom/Zoom_in_(3).jpg")
new_zoom_3 = zoom_3.resize((720, 990))
new_zoom_3.save("zoom/result/New_Zoom_in_(3).jpg")

print(zoom_3.format, zoom_3.size, zoom_3.mode)
print(new_zoom_3.format, new_zoom_3.size, new_zoom_3.mode)
# Out:
# JPEG (250, 330) L
# None (720, 990) L

# %% [markdown]
# ### Zoom_out_(1)

# %%
# Resizing the zoom_out 1
zoom_out_1 = Image.open("zoom/Zoom_out_(1).jpg")
new_zoom_out_1 = zoom_out_1.resize((271, 120))
new_zoom_out_1.save("zoom/result/New_Zoom_out_(1).jpg")

print(zoom_out_1.format, zoom_out_1.size, zoom_out_1.mode)
print(new_zoom_out_1.format, new_zoom_out_1.size, new_zoom_out_1.mode)
# Out:
# JPEG (750, 500) L
# None (271, 120) L

# %% [markdown]
# ### Zoom_out_(2)

# %%
# Resizing the zoom_out 2
zoom_out_2 = Image.open("zoom/Zoom_out_(2).jpg")
new_zoom_out_2 = zoom_out_2.resize((317, 500))
new_zoom_out_2.save("zoom/result/New_Zoom_out_(2).jpg")

print(zoom_out_2.format, zoom_out_2.size, zoom_out_2.mode)
print(new_zoom_out_2.format, new_zoom_out_2.size, new_zoom_out_2.mode)
# Out:
# JPEG (990, 1600) L
# None (317, 500) L

# %% [markdown]
# ### Zoom_out_(3)

# %%
# Resizing the zoom_out 3
zoom_out_3 = Image.open("zoom/Zoom_out_(2).jpg")
new_zoom_out_3 = zoom_out_3.resize((174, 500))
new_zoom_out_3.save("zoom/result/New_Zoom_out_(3).jpg")

print(zoom_out_3.format, zoom_out_3.size, zoom_out_3.mode)
print(new_zoom_out_3.format, new_zoom_out_3.size, new_zoom_out_3.mode)
# Out:
# JPEG (990, 1600) L
# None (174, 500) L

# %% [markdown]
# # Realce

# %% [markdown]
# ### Clarear_(1)

# %%
realce_1 = Image.open("realce/Clarear_(1).jpg")
clarear_1 = ImageEnhance.Brightness(realce_1)

# Faz com que a imagem seja clareada
# Antes tentei 1.5 e ainda estava escura
new_clarear_1 = clarear_1.enhance(5.0)

new_clarear_1.save("realce/result/New_Clarear_(1).jpg")

# %%
image = np.array(Image.open('realce/Clarear_(1).jpg').convert('L')) 
histogram, bin_edges = np.histogram(image,range=(0, 256))
plt.figure()

plt.plot(bin_edges[0:-1], histogram)  
plt.show()

# %%
image = np.array(Image.open('realce/result/New_Clarear_(1).jpg').convert('L')) 
histogram, bin_edges = np.histogram(image,range=(0, 256))
plt.figure()

plt.plot(bin_edges[0:-1], histogram)  
plt.show()

# %% [markdown]
# ### Clarear_(2)

# %%
realce_2 = Image.open("realce/Clarear_(2).jpg")
clarear_2 = ImageEnhance.Brightness(realce_2)

# Faz com que a imagem seja clareada
new_clarear_2 = clarear_2.enhance(5.0)

new_clarear_2.save("realce/result/New_Clarear_(2).jpg")

# %%
image = np.array(Image.open('realce/Clarear_(2).jpg').convert('L')) 
histogram, bin_edges = np.histogram(image,range=(0, 256))
plt.figure()

plt.plot(bin_edges[0:-1], histogram)  
plt.show()

# %%
image = np.array(Image.open('realce/result/New_Clarear_(2).jpg').convert('L')) 
histogram, bin_edges = np.histogram(image,range=(0, 256))
plt.figure()

plt.plot(bin_edges[0:-1], histogram)  
plt.show()

# %% [markdown]
# ### Clarear_(3)

# %%
realce_3 = Image.open("realce/Clarear_(3).jpg")
clarear_3 = ImageEnhance.Brightness(realce_3)

# Faz com que a imagem seja clareada
new_clarear_3 = clarear_3.enhance(5.0)

new_clarear_3.save("realce/result/New_Clarear_(3).jpg")

# %%
image = np.array(Image.open('realce/Clarear_(3).jpg').convert('L')) 
histogram, bin_edges = np.histogram(image,range=(0, 256))
plt.figure()

plt.plot(bin_edges[0:-1], histogram)  
plt.show()

# %%
image = np.array(Image.open('realce/result/New_Clarear_(3).jpg').convert('L')) 
histogram, bin_edges = np.histogram(image,range=(0, 256))
plt.figure()

plt.plot(bin_edges[0:-1], histogram)  
plt.show()

# %% [markdown]
# ### Escurecer_(1)

# %%
realce_4 = Image.open("realce/Escurecer_(1).jpg")
escurecer_1 = ImageEnhance.Brightness(realce_4)

new_escurecer_1 = escurecer_1.enhance(0.5)

new_escurecer_1.save("realce/result/New_Escurecer_(1).jpg")

# %%
image = np.array(Image.open('realce/Escurecer_(1).jpg').convert('L')) 
histogram, bin_edges = np.histogram(image,range=(0, 256))
plt.figure()

plt.plot(bin_edges[0:-1], histogram)  
plt.show()

# %%
image = np.array(Image.open('realce/result/New_Escurecer_(1).jpg').convert('L')) 
histogram, bin_edges = np.histogram(image,range=(0, 256))
plt.figure()

plt.plot(bin_edges[0:-1], histogram)  
plt.show()

# %% [markdown]
# ### Escurecer_(2)

# %%
realce_5 = Image.open("realce/Escurecer_(2).jpg")
escurecer_2 = ImageEnhance.Brightness(realce_5)

new_escurecer_2 = escurecer_2.enhance(0.5)

new_escurecer_2.save("realce/result/New_Escurecer_(2).jpg")

# %%
image = np.array(Image.open('realce/Escurecer_(2).jpg').convert('L')) 
histogram, bin_edges = np.histogram(image,range=(0, 256))
plt.figure()

plt.plot(bin_edges[0:-1], histogram)  
plt.show()

# %%
image = np.array(Image.open('realce/result/New_Escurecer_(2).jpg').convert('L')) 
histogram, bin_edges = np.histogram(image,range=(0, 256))
plt.figure()

plt.plot(bin_edges[0:-1], histogram)  
plt.show()

# %% [markdown]
# ### Escurecer_(3)

# %%
realce_6 = Image.open("realce/Escurecer_(3).jpg")
escurecer_3 = ImageEnhance.Brightness(realce_6)

new_escurecer_3 = escurecer_3.enhance(0.5)

new_escurecer_3.save("realce/result/New_Escurecer_(3).jpg")

# %%
image = np.array(Image.open('realce/Escurecer_(3).jpg').convert('L')) 
histogram, bin_edges = np.histogram(image,range=(0, 256))
plt.figure()

plt.plot(bin_edges[0:-1], histogram)  
plt.show()

# %%
image = np.array(Image.open('realce/result/New_Escurecer_(3).jpg').convert('L')) 
histogram, bin_edges = np.histogram(image,range=(0, 256))
plt.figure()

plt.plot(bin_edges[0:-1], histogram)  
plt.show()
